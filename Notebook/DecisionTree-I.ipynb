# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
import pickle

# para calcular las métricas

from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn import tree

from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder  
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
plt.rcParams["figure.figsize"] = (10,8)

# %% [markdown]
# # Decision Tree

# %%
df_tt = pd.read_csv("../data/preproc.csv", index_col = 0)
df_tt.head(2)
# Out:
#        carat  cut  color  clarity  price
# id
# 0  -1.128026    1      0        6  6.353
# 1   0.669489    0      1        2  9.183

# %%
X = df_tt.drop('price', axis =1)
y = df_tt['price']

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
max_features = np.sqrt(len(X.columns))
max_features
# Out:
# 2.0

# %%
print(regressor.tree_.max_depth)
# Out:
# 22

# %% [markdown]
# # Predicción¶

# %% [markdown]
# Nos traemos el CSV de test limpio

# %%
X_test = pd.read_csv("../data/test_limpio_.csv", index_col = 0)
X_test.head(2)
# Out:
#       carat  cut  color  clarity
# 0 -1.023184    0      5        5
# 1  0.941880    1      5        5

# %%
y_pred_test = regressor.predict(X_test)
y_pred_train = regressor.predict(X)

# %% [markdown]
# # Validación del Modelo

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred_train))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred_train))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred_train)))
print("R2:",  metrics.r2_score(y, y_pred_train))
# Out:
# Mean Absolute Error: 0.08841003850598857
# Mean Squared Error: 0.040876682777854015
# Root Mean Squared Error: 0.20217982782130867
# R2: 0.9604560958905882

# %%
def metricas(y, y_pred_test, y_pred_train, tipo_modelo):
    
    
    resultados = {'Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred_train))}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
dt_resultsI = metricas(y, y_pred_test, y_pred_train, "Decission Tree I")
dt_resultsI
# Out:
#                           0            modelo
# 0  Root Mean Squared Error:  Decission Tree I
# 1                   0.20218  Decission Tree I

# %% [markdown]
# # Probar el modelo en el CSV de test y exportar CSV

# %%
DT_TestValues = pd.DataFrame(y_pred_test)
DT_TestValues.head(3)
# Out:
#           0
# 0  6.244182
# 1  8.396400
# 2  9.287000

# %%
DT_TestValues.reset_index()
DT_TestValues.columns = ["Price"]
DT_TestValues.head(2)
# Out:
#       Price
# 0  6.244182
# 1  8.396400

# %%
DT_TestValues.to_csv("../data/data predict test1.csv", index_label="id")

# %% [markdown]
# # GridSearch

# %%
# Generación del GridSearch
# ==============================================================================

# definimos un diccionario con los hiperparámetros que queremos testear. 
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
# %time
gs.fit(X, y)
# Out:
# CPU times: user 2 µs, sys: 4 µs, total: 6 µs
# Wall time: 5.96 µs
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.248, test=-0.255) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.238, test=-0.240) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.248, test=-0.257) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.247, test=-0.241) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.857, test=-0.843) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.478, test=-0.480) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.731, test=-0.755) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.550, test=-0.560) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.144, test=-0.146) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.678, test=-0.659) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.401, test=-0.401) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.232, test=-0.238) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.746, test=-0.752) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.260, test=-0.252) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0
total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.074, test=-0.073) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.069, test=-0.071) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.064, test=-0.064) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.067, test=-0.072) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.067, test=-0.065) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.063, test=-0.066) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.065, test=-0.063) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.081, test=-0.090) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.065, test=-0.073) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.065, test=-0.063) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.071, test=-0.070) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.085, test=-0.085) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.062, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.063) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.060, test=-0.068) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.060, test=-0.070) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.061, test=-0.065) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.062, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.063) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.061) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.060, test=-0.068) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.070) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.065) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.058) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.068) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.069) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.059) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.065) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# /usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 240 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 1315, in fit
#     super().fit(
#   File "/usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 308, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [-0.44374886 -0.4315224  -0.48784056 -0.24404996 -0.25251357 -0.19659394
#  -0.12970367 -0.13515639 -0.14247615 -0.11227088 -0.11227088 -0.11227088
#          nan         nan         nan         nan         nan         nan
#  -0.37372345 -0.29005102 -0.40510936 -0.16981598 -0.2012223  -0.18281703
#  -0.10949836 -0.10638414 -0.10524029 -0.08716204 -0.08716204 -0.08716204
#          nan         nan         nan         nan         nan         nan
#  -0.30180827 -0.21870635 -0.28833204 -0.16334283 -0.10804167 -0.16630539
#  -0.08187474 -0.08067023 -0.0801729  -0.07100461 -0.07100934 -0.07103944
#          nan         nan         nan         nan         nan         nan
#  -0.2464892  -0.17141083 -0.23326033 -0.12765743 -0.08850572 -0.09622927
#  -0.06695534 -0.06879616 -0.07072672 -0.06214533 -0.06216774 -0.06240018
#          nan         nan         nan         nan         nan         nan]
#   warnings.warn(
# /usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the train scores are non-finite: [-0.44180151 -0.42773067 -0.48658225 -0.24482688 -0.25503449 -0.1969336
#  -0.12951759 -0.13553824 -0.14082765 -0.11186825 -0.11186825 -0.11186825
#          nan         nan         nan         nan         nan         nan
#  -0.36993933 -0.28881457 -0.40824902 -0.16965238 -0.20041623 -0.18130065
#  -0.10904901 -0.10523408 -0.10592004 -0.08649497 -0.08649497 -0.08649497
#          nan         nan         nan         nan         nan         nan
#  -0.30139457 -0.21430151 -0.28494048 -0.16385625 -0.10593202 -0.16459954
#  -0.08118652 -0.08004045 -0.07972409 -0.07019918 -0.07022129 -0.07026801
#          nan         nan         nan         nan         nan         nan
#  -0.2396709  -0.17144655 -0.23031212 -0.1261648  -0.08660651 -0.09352385
#  -0.06535259 -0.06709161 -0.06919252 -0.06105495 -0.06112871 -0.06146353
#          nan         nan         nan         nan         nan         nan]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=4, min_samples_split=10)

# %%
y_pred_testII = best_tree.predict(X_test)
y_pred_trainII = best_tree.predict(X)

# %%
dt_II_results = metricas(y, y_pred_testII, y_pred_trainII, "Decision tree II")

# %%
dt_II_results
# Out:
#                           0            modelo
# 0  Root Mean Squared Error:  Decision tree II
# 1                  0.246883  Decision tree II
