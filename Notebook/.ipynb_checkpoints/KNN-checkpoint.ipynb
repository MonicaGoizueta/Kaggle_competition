# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
import pickle

# para calcular las métricas

from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn import tree

from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder  
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
plt.rcParams["figure.figsize"] = (10,8)

# %%
df_tt = pd.read_csv("../data/preproc.csv", index_col = 0)
df_tt.head()
# Out:
#        carat  cut  color  clarity  price
# id
# 0  -1.128026    1      0        6  6.353
# 1   0.669489    0      1        2  9.183
# 2  -0.064708    0      2        4  7.983
# 3   0.846708    2      3        6  8.371
# 4  -0.976124    1      3        3  6.588

# %%
X = df_tt.drop('price', axis =1)
y = df_tt['price']

# %% [markdown]
# # Pipeline

# %%
pipe = Pipeline(steps=[('estimator', LinearRegression())])

# %%
params_grid = [{
                'estimator':[LinearRegression()],
                },
                {
                'estimator': [DecisionTreeRegressor()],
                'estimator__max_depth': [1,2,3,4,5],
                'estimator__max_features': ["sqrt", "log2"],
                'estimator__min_samples_split': [10, 50, 100], 
                'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[RandomForestRegressor()],
                 'estimator__n_estimators':[50,100,200,300],
                 'estimator__max_depth':[1,2,3,4,5], 
                 'estimator__min_samples_split':[2,3], 
                 'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[KNeighborsRegressor()],
                 'estimator__n_neighbors':[3,5,6,7],
                }

              ]

# %%
grid = GridSearchCV(pipe, params_grid, n_jobs= -1, verbose = 4)

# %%
# %%time
res = grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 215 candidates, totalling 1075 fits
# [CV 3/5] END ......estimator=LinearRegression();, score=0.775 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.020 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.727 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.030 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.024 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.031 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.017 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.012 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.026 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.012 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.012 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.017 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.728 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.015 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.728 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.030 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.717 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.727 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.721 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.717 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.026 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.024 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.029 total time=   0.1s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.721 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.031 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.776 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.730 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.054 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.776 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.768 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.724 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.776 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.730 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.641 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.781 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.724 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.042 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.772 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.789 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.288 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.776 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.770 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.790 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.179 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.735 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.787 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.832 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.728 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.802 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.835 total time=   0.1s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.127 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.792 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.797 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.733 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.100 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.779 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.854 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.829 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.782 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.705 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.522 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.268 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.580 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.730 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.781 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.801 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.854 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.853 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.075 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=3, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.787 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.623 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.873 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.770 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.637 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.861 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.859 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.813 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.812 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.836 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.886 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.844 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=4, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.324 total time=   0.0s
# [CV 2/5] END ......estimator=LinearRegression();, score=0.770 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.721 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.725 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0.717 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.728 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.029 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.030 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.721 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.717 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=50;, score=0.031 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.026 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.012 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=100;, score=0.017 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.727 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.725 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.029 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.030 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.725 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.728 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.030 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=100;, score=0.717 total time=   0.1s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.727 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.012 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.029 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=1, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=10;, score=0.030 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.725 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=100;, score=0.770 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.790 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.503 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.733 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.787 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10;, score=0.721 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=50;, score=0.290 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.643 total time=   0.0s
# [CV 2/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.733 total time=   0.0s
# [CV 3/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.139 total time=   0.0s
# [CV 4/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.639 total time=   0.0s
# [CV 5/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10;, score=0.721 total time=   0.0s
# [CV 1/5] END estimator=DecisionTreeRegressor(), estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=50;, score=0

# [CV 1/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.832 total time=   0.5s
# [CV 3/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.835 total time=   0.5s
# [CV 5/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.830 total time=   0.5s
# [CV 3/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=100;, score=0.835 total time=   1.0s
# [CV 2/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=200;, score=0.831 total time=   2.0s
# [CV 1/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=300;, score=0.832 total time=   3.0s
# [CV 5/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=1, estimator__min_samples_split=3, estimator__n_estimators=300;, score=0.830 total time=   2.9s
# [CV 4/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100;, score=0.831 total time=   1.0s
# [CV 3/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200;, score=0.835 total time=   2.0s
# [CV 2/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=300;, score=0.831 total time=   3.0s
# [CV 1/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.831 total time=   0.5s
# [CV 3/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.834 total time=   0.5s
# [CV 5/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=50;, score=0.830 total time=   0.5s
# [CV 3/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=100;, score=0.835 total time=   1.0s
# [CV 2/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=200;, score=0.831 total time=   2.0s
# [CV 1/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=300;, score=0.832 total time=   2.9s
# [CV 5/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=2, estimator__min_samples_split=3, estimator__n_estimators=300;, score=0.830 total time=   3.1s
# [CV 1/5] END estimator=RandomForestRegressor(), estimator__max_depth=2, estimator__min_samples_leaf=3, estimator__min_samples_split=2, estimator__n_estimators=200;, score=0.832 total time=   2.1s
# CPU times: user 2.25 s, sys: 871 ms, total: 3.12 s
# Wall time: 5min 59s

# %%
best_model = grid.best_params_
best_model
# Out:
# {'estimator': KNeighborsRegressor(), 'estimator__n_neighbors': 5}

# %%
knn = KNeighborsRegressor(n_neighbors = 5)

# %%
knn.fit(X, y)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# # Predicción

# %%
X_test = pd.read_csv("../data/test_limpio_.csv", index_col = 0)
X_test.head(2)
# Out:
#       carat  cut  color  clarity
# 0 -1.023184    0      5        5
# 1  0.941880    1      5        5

# %%
y_pred_knn_test = knn.predict(X_test)
y_pred_knn_train = knn.predict(X)

# %%
y_pred_knn_test
# Out:
# array([6.2784, 8.3964, 9.3708, ..., 6.6374, 8.589 , 7.8802])

# %% [markdown]
# # Validación del Modelo¶

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred_knn_train))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred_knn_train))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred_knn_train)))
print("R2:",  metrics.r2_score(y, y_pred_knn_train))
# Out:
# Mean Absolute Error: 0.10800830814961607
# Mean Squared Error: 0.05299507879613575
# Root Mean Squared Error: 0.23020660024451026
# R2: 0.9487328185221411

# %%
def metricas(y, y_pred_knn_test, y_pred_knn_train, tipo_modelo):
    
    
    resultados = {'Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred_knn_train))}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
KNN_results = metricas(y, y_pred_knn_test, y_pred_knn_train,"KNeighborsRegressor")

# %%
KNN_results
# Out:
#                           0               modelo
# 0                  0.230207  KNeighborsRegressor
# 1  Root Mean Squared Error:  KNeighborsRegressor
